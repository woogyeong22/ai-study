# %%
movie_rank = ["닥터스트레인지", "스플릿", "럭키"]

# %%
movie_rank = ["닥터스트레인지", "스플릿", "럭키"]
movie_rank.append("배트맨") # 추가
print(movie_rank)
# Out:
# ['닥터스트레인지', '스플릿', '럭키', '배트맨']

# %%
movie_rank = ['닥터 스트레인지', '스플릿', '럭키', '배트맨']
movie_rank.insert(1, "슈퍼맨") # 리스트의 1번 인덱스  위치에 "슈퍼맨" 이라는 요소 삽입
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']

# %%
movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '럭키', '배트맨']
del movie_rank [3]
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']

# %%
movie_rank = ['닥터 스트레인지', '슈퍼맨', '스플릿', '배트맨']
del movie_rank[2]       # 리스트에서 어떤 값을 삭제하면 남은 값들은
del movie_rank[2]       # 새로 인덱싱됨
print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨']

# %%
lang1 = ["C", "C++", "JAVA"]
lang2 = ["Python", "Go", "C#"]
langs = lang1 + lang2
print(langs)
# Out:
# ['C', 'C++', 'JAVA', 'Python', 'Go', 'C#']

# %%
nums = [1, 2, 3, 4, 5, 6, 7]
print ("max:",max(nums))
print("min:" , min(nums))
# Out:
# max: 7
# min: 1

# %%
nums = [1, 2, 3, 4, 5]
print(sum(nums))
# Out:
# 15

# %%
cook = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", "쫄면", "소시지", "라면", "팥빙수", "김치전"]
print(len(cook))
# Out:
# 12

# %%
nums = [1, 2, 3, 4, 5]
average = sum(nums) / len(nums) # (1+2+3+4+5 / 5)
print(average)
# Out:
# 3.0
